# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import imdb

import numpy as np
import matplotlib.pyplot as plt

# 解决中文乱码问题
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams['font.size'] = 20
plt.rcParams['font.family'] = ['Adobe Heiti Std']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

# %%
N = 10000

def multi_hot_encoding(sentences, dim=10000):
    results = np.zeros((len(sentences), dim))
    for i, word_indices in enumerate(sentences):
        results[i, word_indices] = 1.0
    return results

# %%
(train_x, train_y), (test_x, test_y) = imdb.load_data(num_words=N)
train_x = multi_hot_encoding(train_x)
test_x = multi_hot_encoding(test_x)
plt.plot(train_x[0])
plt.show()
# Out:
# /Users/sunchao/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1331: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## build the model

# %%
def build_and_train(hidden_dim, regularizer=None, dropout=0):
    model = keras.Sequential([
        keras.layers.Dense(hidden_dim, activation='relu', input_shape=(N,), kernel_regularizer=regularizer),
        keras.layers.Dropout(dropout),
        keras.layers.Dense(hidden_dim, activation='relu', kernel_regularizer=regularizer),
        keras.layers.Dropout(dropout),
        keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'binary_crossentropy'])
    history = model.fit(train_x, train_y, epochs=10, batch_size=512, validation_data=(test_x, test_y), verbose=1)
    return history

# %%
baseline_history = build_and_train(16)
smaller_history = build_and_train(4)
larger_history = build_and_train(128)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/10
# 25000/25000 [==============================] - 8s 313us/sample - loss: 0.4889 - accuracy: 0.8124 - binary_crossentropy: 0.4889 - val_loss: 0.3440 - val_accuracy: 0.8756 - val_binary_crossentropy: 0.3440
# Epoch 2/10
# 25000/25000 [==============================] - 4s 142us/sample - loss: 0.2539 - accuracy: 0.9098 - binary_crossentropy: 0.2539 - val_loss: 0.2838 - val_accuracy: 0.8876 - val_binary_crossentropy: 0.2838
# Epoch 3/10
# 25000/25000 [==============================] - 3s 108us/sample - loss: 0.1856 - accuracy: 0.9349 - binary_crossentropy: 0.1856 - val_loss: 0.2902 - val_accuracy: 0.8844 - val_binary_crossentropy: 0.2902
# Epoch 4/10
# 25000/25000 [==============================] - 3s 115us/sample - loss: 0.1488 - accuracy: 0.9506 - binary_crossentropy: 0.1488 - val_loss: 0.3076 - val_accuracy: 0.8814 - val_binary_crossentropy: 0.3076
# Epoch 5/10
# 25000/25000 [==============================] - 3s 107us/sample - loss: 0.1237 - accuracy: 0.9596 - binary_crossentropy: 0.1237 - val_loss: 0.3348 - val_accuracy: 0.8762 - val_binary_crossentropy: 0.3348
# Epoch 6/10
# 25000/25000 [==============================] - 2s 93us/sample - loss: 0.1036 - accuracy: 0.9681 - binary_crossentropy: 0.1036 - val_loss: 0.3637 - val_accuracy: 0.8727 - val_binary_crossentropy: 0.3637
# Epoch 7/10
# 25000/25000 [==============================] - 3s 113us/sample - loss: 0.0878 - accuracy: 0.9734 - binary_crossentropy: 0.0878 - val_loss: 0.4004 - val_accuracy: 0.8693 - val_binary_crossentropy: 0.4004
# Epoch 8/10
# 25000/25000 [==============================] - 3s 125us/sample - loss: 0.0744 - accuracy: 0.9789 - binary_crossentropy: 0.0744 - val_loss: 0.4352 - val_accuracy: 0.8652 - val_binary_crossentropy: 0.4352
# Epoch 9/10
# 25000/25000 [==============================] - 2s 98us/sample - loss: 0.0619 - accuracy: 0.9838 - binary_crossentropy: 0.0619 - val_loss: 0.4745 - val_accuracy: 0.8603 - val_binary_crossentropy: 0.4745
# Epoch 10/10
# 25000/25000 [==============================] - 2s 90us/sample - loss: 0.0514 - accuracy: 0.9885 - binary_crossentropy: 0.0514 - val_loss: 0.5151 - val_accuracy: 0.8602 - val_binary_crossentropy: 0.5151
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/10
# 25000/25000 [==============================] - 3s 120us/sample - loss: 0.5466 - accuracy: 0.7836 - binary_crossentropy: 0.5466 - val_loss: 0.4360 - val_accuracy: 0.8568 - val_binary_crossentropy: 0.4360
# Epoch 2/10
# 25000/25000 [==============================] - 3s 102us/sample - loss: 0.3467 - accuracy: 0.8900 - binary_crossentropy: 0.3467 - val_loss: 0.3382 - val_accuracy: 0.8776 - val_binary_crossentropy: 0.3382
# Epoch 3/10
# 25000/25000 [==============================] - 2s 96us/sample - loss: 0.2638 - accuracy: 0.9121 - binary_crossentropy: 0.2638 - val_loss: 0.3029 - val_accuracy: 0.8834 - val_binary_crossentropy: 0.3029
# Epoch 4/10
# 25000/25000 [==============================] - 3s 101us/sample - loss: 0.2183 - accuracy: 0.9278 - binary_crossentropy: 0.2183 - val_loss: 0.2875 - val_accuracy: 0.8874 - val_binary_crossentropy: 0.2875
# Epoch 5/10
# 25000/25000 [==============================] - 2s 98us/sample - loss: 0.1884 - accuracy: 0.9379 - binary_crossentropy: 0.1884 - val_loss: 0.2841 - val_accuracy: 0.8863 - val_binary_crossentropy: 0.2841
# Epoch 6/10
# 25000/25000 [==============================] - 3s 104us/sample - loss: 0.1657 - accuracy: 0.9456 - binary_crossentropy: 0.1657 - val_loss: 0.2867 - val_accuracy: 0.8858 - val_binary_crossentropy: 0.2867
# Epoch 7/10
# 25000/25000 [==============================] - 3s 113us/sample - loss: 0.1479 - accuracy: 0.9529 - binary_crossentropy: 0.1479 - val_loss: 0.2941 - val_accuracy: 0.8836 - val_binary_crossentropy: 0.2941
# Epoch 8/10
# 25000/25000 [==============================] - 2s 99us/sample - loss: 0.1331 - accuracy: 0.9576 - binary_crossentropy: 0.1331 - val_loss: 0.3132 - val_accuracy: 0.8773 - val_binary_crossentropy: 0.3132
# Epoch 9/10
# 25000/25000 [==============================] - 3s 109us/sample - loss: 0.1211 - accuracy: 0.9618 - binary_crossentropy: 0.1211 - val_loss: 0.3146 - val_accuracy: 0.8797 - val_binary_crossentropy: 0.3146
# Epoch 10/10
# 25000/25000 [==============================] - 2s 99us/sample - loss: 0.1093 - accuracy: 0.9673 - binary_crossentropy: 0.1093 - val_loss: 0.3280 - val_accuracy: 0.8772 - val_binary_crossentropy: 0.3280
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/10
# 25000/25000 [==============================] - 6s 228us/sample - loss: 0.3716 - accuracy: 0.8420 - binary_crossentropy: 0.3716 - val_loss: 0.2901 - val_accuracy: 0.8828 - val_binary_crossentropy: 0.2901
# Epoch 2/10
# 25000/25000 [==============================] - 4s 165us/sample - loss: 0.1774 - accuracy: 0.9362 - binary_crossentropy: 0.1774 - val_loss: 0.3246 - val_accuracy: 0.8756 - val_binary_crossentropy: 0.3246
# Epoch 3/10
# 25000/25000 [==============================] - 4s 163us/sample - loss: 0.1131 - accuracy: 0.9606 - binary_crossentropy: 0.1131 - val_loss: 0.3915 - val_accuracy: 0.8705 - val_binary_crossentropy: 0.3915
# Epoch 4/10
# 25000/25000 [==============================] - 4s 168us/sample - loss: 0.0600 - accuracy: 0.9822 - binary_crossentropy: 0.0600 - val_loss: 0.4747 - val_accuracy: 0.8642 - val_binary_crossentropy: 0.4747
# Epoch 5/10
# 25000/25000 [==============================] - 4s 170us/sample - loss: 0.0231 - accuracy: 0.9949 - binary_crossentropy: 0.0231 - val_loss: 0.5817 - val_accuracy: 0.8608 - val_binary_crossentropy: 0.5817
# Epoch 6/10
# 25000/25000 [==============================] - 4s 177us/sample - loss: 0.0066 - accuracy: 0.9993 - binary_crossentropy: 0.0066 - val_loss: 0.6504 - val_accuracy: 0.8624 - val_binary_crossentropy: 0.6504
# Epoch 7/10
# 25000/25000 [==============================] - 4s 164us/sample - loss: 0.0020 - accuracy: 1.0000 - binary_crossentropy: 0.0020 - val_loss: 0.7121 - val_accuracy: 0.8624 - val_binary_crossentropy: 0.7121
# Epoch 8/10
# 25000/25000 [==============================] - 4s 164us/sample - loss: 9.7941e-04 - accuracy: 1.0000 - binary_crossentropy: 9.7941e-04 - val_loss: 0.7500 - val_accuracy: 0.8626 - val_binary_crossentropy: 0.7500
# Epoch 9/10
# 25000/25000 [==============================] - 4s 180us/sample - loss: 6.4090e-04 - accuracy: 1.0000 - binary_crossentropy: 6.4090e-04 - val_loss: 0.7783 - val_accuracy: 0.8625 - val_binary_crossentropy: 0.7783
# Epoch 10/10
# 25000/25000 [==============================] - 4s 167us/sample - loss: 4.7124e-04 - accuracy: 1.0000 - binary_crossentropy: 4.7124e-04 - val_loss: 0.7998 - val_accuracy: 0.8624 - val_binary_crossentropy: 0.7998

# %% [markdown]
# # plot the history

# %%
def plot_history(histories, key='binary_crossentropy'):
    plt.figure(figsize=(10, 6))
    for name, history in histories:
        val = plt.plot(history.epoch, history.history['val_'+key],
                       '--', label=name + ' 验证集')
        plt.plot(history.epoch, history.history[key], 
                 color=val[0].get_color(), label=name + ' 训练集')
    plt.xlabel('Epochs')
    plt.ylabel('Loss - ' + key)
    plt.legend()
    plt.xlim([0, max(history.epoch)])

# %%
plot_history([('基线', baseline_history),
              ('较小', smaller_history),
              ('较大', larger_history)])

# %% [markdown]
# ## 使用dropout防止过拟合

# %%
l2_model_history = build_and_train(16, keras.regularizers.l2(0.001))
dpt_model_history = build_and_train(16, dropout=0.2)
plot_history([('基线', baseline_history),
              ('L2正则', l2_model_history),
              ('Dropout', dpt_model_history)])
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/10
# 25000/25000 [==============================] - 4s 161us/sample - loss: 0.5005 - accuracy: 0.8192 - binary_crossentropy: 0.4594 - val_loss: 0.3629 - val_accuracy: 0.8821 - val_binary_crossentropy: 0.3198
# Epoch 2/10
# 25000/25000 [==============================] - 2s 91us/sample - loss: 0.2884 - accuracy: 0.9133 - binary_crossentropy: 0.2421 - val_loss: 0.3338 - val_accuracy: 0.8858 - val_binary_crossentropy: 0.2852
# Epoch 3/10
# 25000/25000 [==============================] - 2s 87us/sample - loss: 0.2413 - accuracy: 0.9333 - binary_crossentropy: 0.1906 - val_loss: 0.3377 - val_accuracy: 0.8856 - val_binary_crossentropy: 0.2853
# Epoch 4/10
# 25000/25000 [==============================] - 2s 90us/sample - loss: 0.2207 - accuracy: 0.9432 - binary_crossentropy: 0.1668 - val_loss: 0.3532 - val_accuracy: 0.8801 - val_binary_crossentropy: 0.2979
# Epoch 5/10
# 25000/25000 [==============================] - 3s 110us/sample - loss: 0.2081 - accuracy: 0.9475 - binary_crossentropy: 0.1515 - val_loss: 0.3693 - val_accuracy: 0.8777 - val_binary_crossentropy: 0.3119
# Epoch 6/10
# 25000/25000 [==============================] - 2s 91us/sample - loss: 0.1957 - accuracy: 0.9542 - binary_crossentropy: 0.1376 - val_loss: 0.3808 - val_accuracy: 0.8747 - val_binary_crossentropy: 0.3222
# Epoch 7/10
# 25000/25000 [==============================] - 2s 98us/sample - loss: 0.1873 - accuracy: 0.9569 - binary_crossentropy: 0.1280 - val_loss: 0.3981 - val_accuracy: 0.8711 - val_binary_crossentropy: 0.3384
# Epoch 8/10
# 25000/25000 [==============================] - 2s 88us/sample - loss: 0.1817 - accuracy: 0.9594 - binary_crossentropy: 0.1216 - val_loss: 0.4127 - val_accuracy: 0.8695 - val_binary_crossentropy: 0.3520
# Epoch 9/10
# 25000/25000 [==============================] - 3s 105us/sample - loss: 0.1770 - accuracy: 0.9614 - binary_crossentropy: 0.1156 - val_loss: 0.4249 - val_accuracy: 0.8671 - val_binary_crossentropy: 0.3631
# Epoch 10/10
# 25000/25000 [==============================] - 2s 97us/sample - loss: 0.1728 - accuracy: 0.9634 - binary_crossentropy: 0.1105 - val_loss: 0.4361 - val_accuracy: 0.8657 - val_binary_crossentropy: 0.3734
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/10
# 25000/25000 [==============================] - 3s 117us/sample - loss: 0.5693 - accuracy: 0.7108 - binary_crossentropy: 0.5693 - val_loss: 0.4211 - val_accuracy: 0.8680 - val_binary_crossentropy: 0.4211
# Epoch 2/10
# 25000/25000 [==============================] - 2s 97us/sample - loss: 0.3658 - accuracy: 0.8676 - binary_crossentropy: 0.3658 - val_loss: 0.3161 - val_accuracy: 0.8842 - val_binary_crossentropy: 0.3161
# Epoch 3/10
# 25000/25000 [==============================] - 2s 89us/sample - loss: 0.2695 - accuracy: 0.9080 - binary_crossentropy: 0.2695 - val_loss: 0.2908 - val_accuracy: 0.8860 - val_binary_crossentropy: 0.2908
# Epoch 4/10
# 25000/25000 [==============================] - 2s 88us/sample - loss: 0.2129 - accuracy: 0.9294 - binary_crossentropy: 0.2129 - val_loss: 0.2909 - val_accuracy: 0.8845 - val_binary_crossentropy: 0.2909
# Epoch 5/10
# 25000/25000 [==============================] - 2s 92us/sample - loss: 0.1681 - accuracy: 0.9452 - binary_crossentropy: 0.1681 - val_loss: 0.3051 - val_accuracy: 0.8801 - val_binary_crossentropy: 0.3051
# Epoch 6/10
# 25000/25000 [==============================] - 2s 92us/sample - loss: 0.1387 - accuracy: 0.9564 - binary_crossentropy: 0.1387 - val_loss: 0.3294 - val_accuracy: 0.8763 - val_binary_crossentropy: 0.3294
# Epoch 7/10
# 25000/25000 [==============================] - 2s 97us/sample - loss: 0.1121 - accuracy: 0.9676 - binary_crossentropy: 0.1121 - val_loss: 0.3646 - val_accuracy: 0.8752 - val_binary_crossentropy: 0.3646
# Epoch 8/10
# 25000/25000 [==============================] - 2s 92us/sample - loss: 0.0913 - accuracy: 0.9748 - binary_crossentropy: 0.0913 - val_loss: 0.3790 - val_accuracy: 0.8723 - val_binary_crossentropy: 0.3790
# Epoch 9/10
# 25000/25000 [==============================] - 2s 93us/sample - loss: 0.0743 - accuracy: 0.9802 - binary_crossentropy: 0.0743 - val_loss: 0.4284 - val_accuracy: 0.8712 - val_binary_crossentropy: 0.4284
# Epoch 10/10
# 25000/25000 [==============================] - 2s 97us/sample - loss: 0.0612 - accuracy: 0.9843 - binary_crossentropy: 0.0612 - val_loss: 0.4458 - val_accuracy: 0.8712 - val_binary_crossentropy: 0.4458
